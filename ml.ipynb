# %%
# install slim version (default): if you get an error message, run it again
# !pip install pycaret

# %%
 #from pycaret.classification import *
 #clf = setup(data=data, target='class', train_size=0.7, session_id=123)

#Run the below code in your notebook to check the installed version
from pycaret.utils import version
version()
from keras.models import Model
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")


# Load libraries
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import KFold, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
# Load digits dataset
digits = datasets.load_digits()

# Create features matrix
features = digits.data

# Create target vector
target = digits.target

# Create standardizer
standardizer = StandardScaler()

# Create logistic regression object
logit = LogisticRegression()

# Create a pipeline that standardizes, then runs logistic regression
pipeline = make_pipeline(standardizer, logit)

import pandas as pd
plt.rcParams['figure.figsize'] = (7,5)

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

'''
#For Google Colab only
from pycaret.utils import enable_colab
enable_colab()


print("Pandas version: ", pd.__version__)
print("Seaborn version: ", sns.__version__)

'''
# Out:
# '\n#For Google Colab only\nfrom pycaret.utils import enable_colab \nenable_colab()\n\n\nprint("Pandas version: ", pd.__version__)\nprint("Seaborn version: ", sns.__version__)\n\n'

# %%
#read cvs file into dataframe
df = pd.read_csv('/sleep-dataset.csv')
df.head(25)

data = df.sample(frac=0.9, random_state=786)
data_unseen = df.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions: ' + str(data_unseen.shape))


from pycaret.classification import *
clf = setup(data=data, target='sl', train_size=0.7, session_id=123)




#show the best model and their statistics
best_model = compare_models()

print(best_model)
# Out:
# Data for Modeling: (567, 7)
# Unseen Data For Predictions: (63, 7)
# <style type="text/css">
# #T_eaf1b_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eaf1b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaf1b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eaf1b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaf1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaf1b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_eaf1b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_eaf1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eaf1b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eaf1b_row1_col1" class="data row1 col1" >sl</td>
#     </tr>
#     <tr>
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   t       630 non-null    float64
#  1   lm      630 non-null    float64
#  2   bo      630 non-null    float64
#  3   rem     630 non-null    float64
#  4   sr      630 non-null    float64
#  5   hr      630 non-null    float64
#  6   sl      630 non-null    int64
# dtypes: float64(6), int64(1)
# memory usage: 34.6 KB

# %%
top3 = compare_models(n_select=4)
# Out:
# <style type="text/css">
# #T_57511 th {
#   text-align: left;
# }
# ...

# %%
print(top3)
# Out:
# [LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False), KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=-1, n_neighbors=5, p=2,
#                      weights='uniform'), GaussianNB(priors=None, var_smoothing=1e-09), LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)]

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_4fd59_row10_col0, #T_4fd59_row10_col1, #T_4fd59_row10_col2, #T_4fd59_row10_col3, #T_4fd59_row10_col4, #T_4fd59_row10_col5, #T_4fd59_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4fd59" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fd59_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4fd59_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4fd59_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4fd59_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4fd59_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4fd59_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4fd59_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_f3328_row10_col0, #T_f3328_row10_col1, #T_f3328_row10_col2, #T_f3328_row10_col3, #T_f3328_row10_col4, #T_f3328_row10_col5, #T_f3328_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f3328" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3328_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f3328_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f3328_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f3328_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f3328_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f3328_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f3328_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_dt
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=16, max_features='log2', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0002, min_samples_leaf=3,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %%
# !pip install statsmodels --upgrade

# %%
evaluate_model(tuned_dt)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_09e9f_row10_col0, #T_09e9f_row10_col1, #T_09e9f_row10_col2, #T_09e9f_row10_col3, #T_09e9f_row10_col4, #T_09e9f_row10_col5, #T_09e9f_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_09e9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09e9f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_09e9f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_09e9f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_09e9f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_09e9f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_09e9f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_09e9f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_knn = tune_model(knn, custom_grid = {'n_neighbors' : np.arange(0,356,1)})
# Out:
# <style type="text/css">
# #T_4b8fc_row10_col0, #T_4b8fc_row10_col1, #T_4b8fc_row10_col2, #T_4b8fc_row10_col3, #T_4b8fc_row10_col4, #T_4b8fc_row10_col5, #T_4b8fc_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4b8fc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b8fc_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4b8fc_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4b8fc_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4b8fc_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4b8fc_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4b8fc_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4b8fc_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_knn)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
lr = create_model('lr')
# Out:
# <style type="text/css">
# #T_d48b7_row10_col0, #T_d48b7_row10_col1, #T_d48b7_row10_col2, #T_d48b7_row10_col3, #T_d48b7_row10_col4, #T_d48b7_row10_col5, #T_d48b7_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d48b7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d48b7_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_d48b7_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_d48b7_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_d48b7_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_d48b7_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_d48b7_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_d48b7_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_lr = tune_model(lr)
# Out:
# <style type="text/css">
# #T_7e488_row10_col0, #T_7e488_row10_col1, #T_7e488_row10_col2, #T_7e488_row10_col3, #T_7e488_row10_col4, #T_7e488_row10_col5, #T_7e488_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7e488" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e488_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7e488_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7e488_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7e488_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7e488_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7e488_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7e488_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_lr)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_24109_row10_col0, #T_24109_row10_col1, #T_24109_row10_col2, #T_24109_row10_col3, #T_24109_row10_col4, #T_24109_row10_col5, #T_24109_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_24109" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24109_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_24109_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_24109_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_24109_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_24109_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_24109_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_24109_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_rf = tune_model(rf)
# Out:
# <style type="text/css">
# #T_a75a5_row10_col0, #T_a75a5_row10_col1, #T_a75a5_row10_col2, #T_a75a5_row10_col3, #T_a75a5_row10_col4, #T_a75a5_row10_col5, #T_a75a5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a75a5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a75a5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a75a5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a75a5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a75a5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a75a5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a75a5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a75a5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_best_model = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_2707c_row10_col0, #T_2707c_row10_col1, #T_2707c_row10_col2, #T_2707c_row10_col3, #T_2707c_row10_col4, #T_2707c_row10_col5, #T_2707c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2707c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2707c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2707c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2707c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2707c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2707c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2707c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2707c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_best_model
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
clf_pca = setup(data=data, target='sl', train_size=0.7, session_id=123, normalize = True, pca = True, pca_components = 3)
# Out:
# <style type="text/css">
# #T_b58f9_row8_col1, #T_b58f9_row12_col1, #T_b58f9_row14_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b58f9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b58f9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b58f9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b58f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b58f9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b58f9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b58f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b58f9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b58f9_row1_col1" class="data row1 col1" >sl</td>
#     </tr>
#     <tr>
# ...

# %%
best_model_pca = compare_models()
# Out:
# <style type="text/css">
# #T_45140 th {
#   text-align: left;
# }
# ...

# %%
best_model_pca
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Tune hyperparameters with scikit-learn (default)
tuned_best_model_pca = tune_model(best_model_pca)
# Out:
# <style type="text/css">
# #T_50eb5_row10_col0, #T_50eb5_row10_col1, #T_50eb5_row10_col2, #T_50eb5_row10_col3, #T_50eb5_row10_col4, #T_50eb5_row10_col5, #T_50eb5_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_50eb5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50eb5_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_50eb5_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_50eb5_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_50eb5_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_50eb5_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_50eb5_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_50eb5_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
tuned_best_model_pca
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
evaluate_model(tuned_best_model_pca)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 9.4 MB/s eta 0:00:00
# ...

# %%
import shap

# %%
lr_pca_shap = create_model('lr')
tuned_lr_pca_shap = tune_model(lr_pca_shap)
# Out:
# <style type="text/css">
# #T_9d03b_row10_col0, #T_9d03b_row10_col1, #T_9d03b_row10_col2, #T_9d03b_row10_col3, #T_9d03b_row10_col4, #T_9d03b_row10_col5, #T_9d03b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9d03b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d03b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9d03b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9d03b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9d03b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9d03b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9d03b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9d03b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
plot_model(lr_pca_shap, plot = 'auc', scale=5)

# %% [markdown]
# Decision Tree

# %%
dt_pca = create_model('dt')
tuned_dt_pca = tune_model(dt_pca)
interpret_model(tuned_dt_pca, plot='summary')
interpret_model(tuned_dt_pca, plot='reason', observation=35)
interpret_model(tuned_dt_pca, plot='reason')
# Out:
# <style type="text/css">
# #T_4e527_row10_col0, #T_4e527_row10_col1, #T_4e527_row10_col2, #T_4e527_row10_col3, #T_4e527_row10_col4, #T_4e527_row10_col5, #T_4e527_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_4e527" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e527_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_4e527_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_4e527_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_4e527_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_4e527_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_4e527_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_4e527_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [markdown]
# Random forest

# %%
rf_pca = create_model('rf')

# %%
tuned_rf_pca = tune_model(rf_pca)

# %%
interpret_model(tuned_rf_pca, plot='summary')

# %%
interpret_model(tuned_rf_pca, plot='reason', observation=35)

# %%
interpret_model(tuned_rf_pca, plot='reason')
